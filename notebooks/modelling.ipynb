# %% [markdown]
# # **MLProcess - Air Quality**
# ---
# **4 - Modeling, Tuning, and Evaluation**

# %%
# Import the required libraries.
import copy
import hashlib
import json

# Need to be installed.
import joblib
import time
import yaml
import pandas as pd
import numpy as np

from sklearn.dummy import DummyClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.tree import DecisionTreeClassifier as DTC
from sklearn.linear_model import LogisticRegression as LGR
from sklearn.ensemble import BaggingClassifier as BGC, RandomForestClassifier as RFC, AdaBoostClassifier as ABC, GradientBoostingClassifier as GBC

from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

from datetime import datetime
from tqdm import tqdm

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## **0 - Configuration File**
# ---

# %%
# Function to load configuration parameter.
def load_config(path_config):
    """
    Load the configuration file (config.yaml).

    Parameters:
    ----------
    path_config : str
        Configuration file location.

    Returns:
    -------
    params : dict
        The configuration parameters.
    """

    # Try to load config.yaml file.
    try:
        with open(path_config, 'r') as file:
            params = yaml.safe_load(file)
    except FileNotFoundError as err:
        raise RuntimeError(f"Configuration file not found in {path_config}")

    return params

# %%
# Function to update configuration parameter.
def update_config(key, value, params, path_config):
    """
    Update the configuration parameter values.

    Parameters:
    ----------
    key : str
        The key to be updated.

    value : any type supported in Python
        The updated value.

    params : dict
        Loaded configuration parameters.

    path_config : str
        Configuration file location.

    Returns:
    -------
    config : dict
        Updated configuration parameters.
    """

    # To maintain the raw config immutable.
    params = params.copy()

    # Update the configuration parameters.
    params[key] = value

    with open(path_config, 'w') as file:
        yaml.dump(params, file)

    print(f"Params Updated! \nKey: {key} \nValue: {value}\n")

    # Reload the updated configuration parameters.
    config = load_config(path_config)

    return config

# %%
# Load the configuration file.
PATH_CONFIG = "../config/config.yaml"
config = load_config(PATH_CONFIG)

# %%
# Check the configuration parameters.
config
# Out:
# {'columns_datetime': ['tanggal'],
#  'columns_int': ['pm10', 'pm25', 'so2', 'co', 'o3', 'no2', 'max'],
#  'columns_object': ['stasiun', 'critical', 'category'],
#  'features': ['stasiun', 'pm10', 'pm25', 'so2', 'co', 'o3', 'no2'],
#  'impute_co': 11.0,
#  'impute_no2': 18.0,
#  'impute_o3': 28.0,
#  'impute_pm10': {'BAIK': 28.46853146853147, 'TIDAK BAIK': 55.55940204563336},
#  'impute_pm25': {'BAIK': 39.67567567567568, 'TIDAK BAIK': 82.7992125984252},
#  'impute_so2': 35.236574746008706,
#  'label': 'category',
#  'label_categories': ['BAIK', 'SEDANG', 'TIDAK SEHAT'],
#  'label_categories_new': ['BAIK', 'TIDAK BAIK'],
#  'path_joined_data': '../data/interim/joined_dataset.pkl',
#  'path_ohe_stasiun': '../models/ohe_stasiun.pkl',
#  'path_raw_data': '../data/raw/',
#  'path_test_set': ['../data/interim/X_test.pkl', '../data/interim/y_test.pkl'],
#  'path_train_set': ['../data/interim/X_train.pkl',
#   '../data/interim/y_train.pkl'],
#  'path_valid_set': ['../data/interim/X_valid.pkl',
#   '../data/interim/y_valid.pkl'],
#  'path_validated_data': '../data/interim/validated_data.pkl',
#  'range_co': [-1, 47],
#  'range_no2': [-1, 65],
#  'range_o3': [-1, 151],
#  'range_pm10': [-1, 179],
#  'range_pm25': [-1, 174],
#  'range_so2': [-1, 82],
#  'range_stasiun': ['DKI1 (Bunderan HI)',
#   'DKI2 (Kelapa Gading)',
#   'DKI3 (Jagakarsa)',
#   'DKI4 (Lubang Buaya)',
#   'DKI5 (Kebon Jeruk) Jakarta Barat']}

# %% [markdown]
# ## **1 - Load Data**
# ---

# %%
# Undersampling
X_rus = joblib.load(f"../data/processed/X_rus.pkl")
y_rus = joblib.load(f"../data/processed/y_rus.pkl")

# Oversampling
X_ros = joblib.load(f"../data/processed/X_ros.pkl")
y_ros = joblib.load(f"../data/processed/y_ros.pkl")

# Smote
X_sm = joblib.load(f"../data/processed/X_sm.pkl")
y_sm = joblib.load(f"../data/processed/y_sm.pkl")

# Valid
X_valid = joblib.load('../data/processed/X_valid_feng.pkl')
y_valid = joblib.load('../data/processed/y_valid_feng.pkl')

# Test
X_test = joblib.load('../data/processed/X_test_feng.pkl')
y_test = joblib.load('../data/processed/y_test_feng.pkl')

# %% [markdown]
# ## **2 - Training Log**
# ---

# %%
# Function to support training log.
def time_stamp():
    return datetime.now()

def create_log_template():
    logger = {
        'model_name' : [],
        'model_id' : [],
        'training_time' : [],
        'training_date' : [],
        'performance' : [],
        'f1_score_avg' : [],
        'data_configuration' : []
    }
    
    return logger

# %%
def update_training_log(current_log, path_log):
    """
    Update the training log.

    Parameters:
    ----------
    current_log : dict
        The training log current state.

    path_log : str
        The directory of training log.

    Returns:
    -------
    last_log : dict
        The updated training log.
    """

    # Ensure the current log immutable.
    current_log = current_log.copy()

    # Open the training log file.
    try:
        with open(path_log, 'r') as file:
            last_log = json.load(file)
    # If the training log does not exists.
    except FileNotFoundError as err:
        # Create the new training log.
        with open(path_log, 'w') as file:
            file.write("[]")

        # Reload the current training log.
        with open(path_log, 'r') as file:
            last_log = json.load(file)

    last_log.append(current_log)

    # Rewrite the training log with the updated one.
    with open(path_log, 'w') as file:
        json.dump(last_log, file)

    return last_log

# %% [markdown]
# ## **3 - Model Training**
# ---

# %%
# Create model object.
baseline = DummyClassifier()
knn = KNN()
dtc = DTC()
lgr = LGR()
bgc = BGC()
rfc = RFC()
abc = ABC()
gbc = GBC()

# %%
list_of_model = {
    "undersampling": [
        {"model_name": baseline.__class__.__name__, "model_object": baseline, "model_id": ""},
        {"model_name": knn.__class__.__name__, "model_object": knn, "model_id": ""},
        {"model_name": dtc.__class__.__name__, "model_object": dtc, "model_id": ""},
        {"model_name": lgr.__class__.__name__, "model_object": lgr, "model_id": ""},
        {"model_name": bgc.__class__.__name__, "model_object": bgc, "model_id": ""},
        {"model_name": rfc.__class__.__name__, "model_object": rfc, "model_id": ""},
        {"model_name": abc.__class__.__name__, "model_object": abc, "model_id": ""},
        {"model_name": gbc.__class__.__name__, "model_object": gbc, "model_id": ""}
    ],
    "oversampling": [
        {"model_name": baseline.__class__.__name__, "model_object": baseline, "model_id": ""},
        {"model_name": knn.__class__.__name__, "model_object": knn, "model_id": ""},
        {"model_name": dtc.__class__.__name__, "model_object": dtc, "model_id": ""},
        {"model_name": lgr.__class__.__name__, "model_object": lgr, "model_id": ""},
        {"model_name": bgc.__class__.__name__, "model_object": bgc, "model_id": ""},
        {"model_name": rfc.__class__.__name__, "model_object": rfc, "model_id": ""},
        {"model_name": abc.__class__.__name__, "model_object": abc, "model_id": ""},
        {"model_name": gbc.__class__.__name__, "model_object": gbc, "model_id": ""}
    ],
    "smote": [
        {"model_name": baseline.__class__.__name__, "model_object": baseline, "model_id": ""},
        {"model_name": knn.__class__.__name__, "model_object": knn, "model_id": ""},
        {"model_name": dtc.__class__.__name__, "model_object": dtc, "model_id": ""},
        {"model_name": lgr.__class__.__name__, "model_object": lgr, "model_id": ""},
        {"model_name": bgc.__class__.__name__, "model_object": bgc, "model_id": ""},
        {"model_name": rfc.__class__.__name__, "model_object": rfc, "model_id": ""},
        {"model_name": abc.__class__.__name__, "model_object": abc, "model_id": ""},
        {"model_name": gbc.__class__.__name__, "model_object": gbc, "model_id": ""}
    ]
}

# %%
def train_eval_model(list_of_model, prefix_model_name, X_train, y_train, data_configuration, X_valid, y_valid, path_log):
    list_of_model = copy.deepcopy(list_of_model)
    
    logger = create_log_template()
    
    for model in tqdm(list_of_model):
        model_name = f"{prefix_model_name} - {model['model_name']}"
        
        start_time = time_stamp()
        model['model_object'].fit(X_train, y_train)
        finished_time = time_stamp()
        
        elapsed_time = finished_time - start_time
        elapsed_time = elapsed_time.total_seconds()
        
        y_pred = model['model_object'].predict(X_valid)
        performance = classification_report(y_valid, y_pred, output_dict=True)
        
        plain_id = str(start_time) + str(finished_time)
        cipher_id = hashlib.md5(plain_id.encode()).hexdigest()
        
        model['model_id'] = cipher_id
        
        logger['model_name'].append(model_name)
        logger['model_id'].append(cipher_id)
        logger['training_time'].append(elapsed_time)
        logger['training_date'].append(str(start_time))
        logger['performance'].append(performance)
        logger['f1_score_avg'].append(performance['macro avg']['f1-score'])
        logger['data_configuration'].append(data_configuration)
        
    training_log = update_training_log(logger, path_log)        
    
    return training_log, list_of_model

# %%
PATH_LOG = "../logs/training_log.json"

training_log, list_of_model_rus = train_eval_model(
    list_of_model = list_of_model['undersampling'],
    prefix_model_name = "first",
    X_train = X_rus,
    y_train = y_rus,
    data_configuration = "undersampling",
    X_valid = X_valid,
    y_valid = y_valid,
    path_log = PATH_LOG
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 11.39it/s]

# %%
list_of_model['undersampling'] = copy.deepcopy(list_of_model_rus)

# %%
training_log, list_of_model_ros = train_eval_model(
    list_of_model['oversampling'],
    "first",
    X_ros,
    y_ros,
    "oversampling",
    X_valid,
    y_valid,
    PATH_LOG
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00,  8.64it/s]

# %%
list_of_model['oversampling'] = copy.deepcopy(list_of_model_ros)

# %%
training_log, list_of_model_sm = train_eval_model(
    list_of_model['smote'],
    "first",
    X_sm,
    y_sm,
    "smote",
    X_valid,
    y_valid,
    PATH_LOG
)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  6.93it/s]

# %%
list_of_model['smote'] = copy.deepcopy(list_of_model_sm)

# %%
def training_log_to_df(training_log):
    training_res = pd.DataFrame()
    
    for log in tqdm(training_log):
        training_res = pd.concat([training_res, pd.DataFrame(log)])
        
    training_res.sort_values(['f1_score_avg', 'training_time'],
                             ascending = [False, True],
                             inplace = True)
    
    training_res.reset_index(inplace=True, drop=True)
    
    return training_res

# %%
training_res = training_log_to_df(training_log)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 80.55it/s]

# %%
training_res
# Out:
#                             model_name                          model_id  \
# 0       first - DecisionTreeClassifier  3a80d00f91fa91463c641b176225b820
# 1       first - DecisionTreeClassifier  b24bca64f5557643685ac2d0bdfecb51
# 2       first - DecisionTreeClassifier  5b7a231de89767ad1e6a3fda52591d98
# 3            first - BaggingClassifier  bf4036bf76b1421ff5de5b54d2618673
# 4            first - BaggingClassifier  5e287d2109b8af8265981a2af22e47cd
# 5   first - GradientBoostingClassifier  b662709b174ad997c2a306022a93522f
# 6           first - AdaBoostClassifier  ddc42cd9ca9a4c73cbe11db77adaa839
# 7           first - AdaBoostClassifier  6beefbfaebb44d95dd33c5685af81e63
# 8       first - RandomForestClassifier  e8fe5af848a2aad327c68e1cf9907a98
# 9       first - RandomForestClassifier  6d1158251c0e70e8fc7245faaf0bc856
# 10  first - GradientBoostingClassifier  6bdc0e7d634e0eb775153a551844377b
# 11  first - GradientBoostingClassifier  178d73a9c6b039a47732b0ff12b7b4ed
# 12        first - KNeighborsClassifier  8031aca8ecd9548226386b9cb2311f71
# 13        first - KNeighborsClassifier  0ac4c9d66d69a5af9d442ca994458d2f
# 14          first - AdaBoostClassifier  eba62fa7fb40430ae5e046d8e177a555
# 15           first - BaggingClassifier  3881b3eb785e5de8e2d9f016e1986b61
# 16          first - LogisticRegression  6c6c02f7e5e86b34d5ac02c4fccf0162
# 17      first - RandomForestClassifier  fc485d43be39bf6c7b338381f054657c
# 18          first - LogisticRegression  781195388af6e79d9b36916c3ad39d45
# 19          first - LogisticRegression  e60c66c17bdacd93dbfdbafc365e8d46
# 20        first - KNeighborsClassifier  4598d362e6a111eb6ceeebde12d25238
# 21             first - DummyClassifier  44ed467f5d3c4320e794a6a74c7479ea
# 22             first - DummyClassifier  fbd9c97c19517f4bd61f178bafa9ca8f
# 23             first - DummyClassifier  b9c08d83bb1395f3163664f670073e2c
#
#     training_time               training_date  \
# 0        0.008212  2026-02-11 14:44:11.434652
# 1        0.009110  2026-02-11 14:44:00.549220
# 2        0.012877  2026-02-11 14:42:52.958539
# 3        0.040088  2026-02-11 14:44:00.678126
# 4        0.058612  2026-02-11 14:44:11.552819
# 5        0.109006  2026-02-11 14:42:53.358723
# 6        0.129618  2026-02-11 14:44:00.978678
# 7        0.157268  2026-02-11 14:44:11.901703
# 8        0.229874  2026-02-11 14:44:00.730343
# 9        0.259909  2026-02-11 14:44:11.624665
# 10       0.298193  2026-02-11 14:44:01.127783
# 11       0.460632  2026-02-11 14:44:12.074949
# 12       0.006184  2026-02-11 14:44:00.523515
# 13       0.007403  2026-02-11 14:44:11.405251
# 14       0.083134  2026-02-11 14:42:53.259088
# 15       0.032498  2026-02-11 14:42:53.031530
# 16       0.087024  2026-02-11 14:44:00.569938
# 17       0.160124  2026-02-11 14:42:53.081801
# 18       0.084645  2026-02-11 14:44:11.452161
# 19       0.037924  2026-02-11 14:42:52.982029
# 20       0.088561  2026-02-11 14:42:52.845518
# 21       0.001593  2026-02-11 14:44:11.393090
# 22       0.002336  2026-02-11 14:44:00.508698
# 23       0.037863  2026-02-11 14:42:52.774640
#
#                                           performance  f1_score_avg  \
# 0   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 1   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 2   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 3   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 4   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 5   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 6   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 7   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 8   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 9   {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 10  {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 11  {'0': {'precision': 1.0, 'recall': 1.0, 'f1-sc...      1.000000
# 12  {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 13  {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 14  {'0': {'precision': 0.95, 'recall': 1.0, 'f1-s...      0.985631
# 15  {'0': {'precision': 0.9047619047619048, 'recal...      0.971894
# 16  {'0': {'precision': 0.7916666666666666, 'recal...      0.934023
# 17  {'0': {'precision': 0.7916666666666666, 'recal...      0.934023
# 18  {'0': {'precision': 0.76, 'recall': 1.0, 'f1-s...      0.922384
# 19  {'0': {'precision': 0.5454545454545454, 'recal...      0.820347
# 20  {'0': {'precision': 0.5135135135135135, 'recal...      0.809874
# 21  {'0': {'precision': 0.10497237569060773, 'reca...      0.095000
# 22  {'0': {'precision': 0.10497237569060773, 'reca...      0.095000
# 23  {'0': {'precision': 0.10497237569060773, 'reca...      0.095000
#
#    data_configuration
# 0               smote
# 1        oversampling
# 2       undersampling
# 3        oversampling
# 4               smote
# 5       undersampling
# 6        oversampling
# 7               smote
# 8        oversampling
# 9               smote
# 10       oversampling
# 11              smote
# 12       oversampling
# 13              smote
# 14      undersampling
# 15      undersampling
# 16       oversampling
# 17      undersampling
# 18              smote
# 19      undersampling
# 20      undersampling
# 21              smote
# 22       oversampling
# 23      undersampling

# %% [markdown]
# ## **4 - Model Tuning**
# ---

# %%
# Function to evaluate model.
def evaluate_model(estimator, param_space, X_train, y_train):
    """
    Do hyperparameter tuning and cross validation.
    """
    
    # Create tuner object.
    tuner = RandomizedSearchCV(
        estimator = estimator,
        param_distributions = param_space,
        n_iter = 100,
        # param_grid = param_space,
        scoring = "f1",
        cv = 5,
        return_train_score = True,
        n_jobs = -1,
        verbose = 1
    )

    # Fit the tuner -> CV + HT.
    tuner.fit(X_train, y_train)

    # Get the best model.
    best_model = tuner.best_estimator_

    # Predict the data.
    pred = best_model.predict(X_train)

    # Get the scores from the best model.
    best_index = tuner.best_index_
    train_f1 = tuner.cv_results_["mean_train_score"][best_index]
    cv_f1 = tuner.cv_results_["mean_test_score"][best_index]

    print(f"Train F1 : {train_f1}")
    print(f"CV F1    : {cv_f1}")

    return best_model, train_f1, cv_f1

# %%
# Hyperparameter for KNN.
knn_params = {
    "n_neighbors": np.arange(1, 13),
    "weights": ["uniform", "distance"],
    "p": [1, 2]
}

# Hyperparameter for LGR.
C = [0.01, 0.1, 1.0, 10.0]

# Hyperparameter for DTC, RFC, and GBC.
DEPTH = np.arange(1, 13)

# Hyperparameter for BGC, RFC, ABC, and GBC.
B = [10, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500]

# Hyperparameter for ABC and GBC.
LR = [0.001, 0.01, 0.05, 0.1, 1]

# %% [markdown]
# Assume that we tune our model on smote data.

# %% [markdown]
# ### KNN

# %%
# Record the start time.
start_time = time.time()

# Evaluate the model.
knn_best_sm, knn_f1_sm, knn_f1_cv_sm = evaluate_model(
    estimator = knn,
    param_space = knn_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

knn_best_sm
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Train F1 : 1.0
# CV F1    : 0.9851360007412152
# Fitting Time : 00 minutes 09 seconds
# KNeighborsClassifier(n_neighbors=np.int64(1), p=1)

# %% [markdown]
# ### LGR

# %%
# Define hyperparameter space.
lgr_params = {
    "C": C
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
lgr_best_sm, lgr_f1_sm, lgr_f1_cv_sm = evaluate_model(
    estimator = lgr,
    param_space = lgr_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

lgr_best_sm
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# Train F1 : 0.9786235037379409
# CV F1    : 0.9765569152294284
# Fitting Time : 00 minutes 00 seconds
# LogisticRegression(C=10.0)

# %% [markdown]
# ### DTC

# %%
# Define hyperparameter space.
dtc_params = {
    "max_depth": DEPTH
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
dtc_best_sm, dtc_f1_sm, dtc_f1_cv_sm = evaluate_model(
    estimator = dtc,
    param_space = dtc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

dtc_best_sm
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# Train F1 : 1.0
# CV F1    : 0.9984585627358917
# Fitting Time : 00 minutes 00 seconds
# DecisionTreeClassifier(max_depth=np.int64(4))

# %% [markdown]
# ### BGC

# %%
# Define hyperparameter space.
bgc_params = {
    "n_estimators": B
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
bgc_best_sm, bgc_f1_sm, bgc_f1_cv_sm = evaluate_model(
    estimator = bgc,
    param_space = bgc_params,
    X_train = X_sm,
    y_train = y_sm
)


# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

bgc_best_sm
# Out:
# Fitting 5 folds for each of 11 candidates, totalling 55 fits
# Train F1 : 0.9997111216764395
# CV F1    : 0.9988424398952007
# Fitting Time : 00 minutes 08 seconds
# BaggingClassifier()

# %% [markdown]
# ### RFC

# %%
# Define hyperparameter space.
rfc_params = {
    "n_estimators": B,
    "max_depth": DEPTH
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
rfc_best_sm, rfc_f1_sm, rfc_f1_cv_sm = evaluate_model(
    estimator = rfc,
    param_space = rfc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

rfc_best_sm
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Train F1 : 1.0
# CV F1    : 0.9992277963499214
# Fitting Time : 00 minutes 55 seconds
# RandomForestClassifier(max_depth=np.int64(9), n_estimators=150)

# %% [markdown]
# ### ABC

# %%
# Define hyperparameter space.
abc_params = {
    "n_estimators": B,
    "learning_rate": LR
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
abc_best_sm, abc_f1_sm, abc_f1_cv_sm = evaluate_model(
    estimator = abc,
    param_space = abc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

abc_best_sm
# Out:
# Fitting 5 folds for each of 55 candidates, totalling 275 fits
# Train F1 : 1.0
# CV F1    : 0.9984732824427482
# Fitting Time : 00 minutes 33 seconds
# AdaBoostClassifier(learning_rate=1, n_estimators=150)

# %% [markdown]
# ### GBC

# %%
# Define hyperparameter space.
gbc_params = {
    "n_estimators": B,
    "learning_rate": LR,
    "max_depth": DEPTH
}

# Record the start time.
start_time = time.time()

# Evaluate the model.
gbc_best_sm, gbc_f1_sm, gbc_f1_cv_sm = evaluate_model(
    estimator = gbc,
    param_space = gbc_params,
    X_train = X_sm,
    y_train = y_sm
)

# Record the end time.
end_time = time.time()

# Calculate the total fitting time.
fitting_time = end_time - start_time
minutes, seconds = divmod(fitting_time, 60)
print(f"Fitting Time : {int(minutes):02d} minutes {int(seconds):02d} seconds\n")

gbc_best_sm
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# Train F1 : 1.0
# CV F1    : 0.9992277963499214
# Fitting Time : 00 minutes 59 seconds
# GradientBoostingClassifier(learning_rate=1, max_depth=np.int64(2),
#                            n_estimators=500)

# %% [markdown]
# ## **4 - Performance Summary**
# ---

# %%
# Create a summary dataframe of train vs CV performance.
performance = {
    "Model": ["KNN", "LGR", "DTC", "BGC", "RFC", "ABC", "GBC"],
    "Train F1": [knn_f1_sm, lgr_f1_sm, dtc_f1_sm, bgc_f1_sm, rfc_f1_sm, abc_f1_sm, gbc_f1_sm],
    "CV F1": [knn_f1_cv_sm, lgr_f1_cv_sm, dtc_f1_cv_sm, bgc_f1_cv_sm, rfc_f1_cv_sm, abc_f1_cv_sm, gbc_f1_cv_sm]
}

summary_df = pd.DataFrame(performance)
summary_df
# Out:
#   Model  Train F1     CV F1
# 0   KNN  1.000000  0.985136
# 1   LGR  0.978624  0.976557
# 2   DTC  1.000000  0.998459
# 3   BGC  0.999711  0.998842
# 4   RFC  1.000000  0.999228
# 5   ABC  1.000000  0.998473
# 6   GBC  1.000000  0.999228

# %% [markdown]
# ## **5 - Model Serialization**
# ---

# %%
# Model Serialization.
PATH_PRODUCTION_MODEL = "../models/best_model.pkl"
joblib.dump(dtc_best_sm, PATH_PRODUCTION_MODEL)
# Out:
# ['../models/best_model.pkl']

# %%
# Update the configuration parameter.
config = update_config(
    key = "path_production_model",
    value = PATH_PRODUCTION_MODEL,
    params = config,
    path_config = PATH_CONFIG
)
# Out:
# Params Updated!
# Key: path_production_model
# Value: ../models/best_model.pkl
